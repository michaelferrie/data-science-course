# %% [markdown]
# # PDA data science - CPI 2023
# <div class="alert alert-block alert-info">
#     Notebook 8: by michael.ferrie@edinburghcollege.ac.uk <br> Edinburgh College, April 2022
# </div>

# %% [markdown]
# #### Consumer price index (CPI) and inflation
#
# The CPI is a measure of consumer price inflation produced to international standards and in line with European regulations. The CPI is the inflation measure used in the government’s target for inflation.
#
# A lot has changed in the past two years and the British economy is currently experiencing rising inflation, according to the [ONS](https://www.ons.gov.uk/economy/inflationandpriceindices/bulletins/consumerpriceinflation/latest#annual-cpih-inflation-rate). The Consumer Prices Index (CPI) rose by 6.2% in the 12 months to February 2022, up from 5.5% to January. This is the highest CPI 12-month inflation rate in the National Statistic series which began in January 1997, and the highest rate in the historic modelled series since March 1992, when it stood at 7.1%.
#
# #### OECD Dataset
#
# ![**OECD Logo**](data:image/jpeg;base64,...
# )
#
# For those of you who have studied our NPA Data Science course, you should be familiar with the CPI. The CPI dataset used in our NPA course was sourced from the IMF. In this notebook we are going to examine a dataset from the [Organisation for Economic
# Co-operation and Development](https://www.oecd.org/about/) (OECD).
#
# This dataset is called the OECD Inflation forecast
# A data mappiong and visualisation tool can be found [here](https://data.oecd.org/price/inflation-forecast.htm#indicator-chart)_
# OECD (2022), Inflation forecast (indicator). doi: 10.1787/598f4aa4-en (Accessed on 02 April 2022)
#
# In the dataset we have a time series of inflation measures per county, the date has been updated to include 2022 and even a 2023 forecast. In the dataset the inflation forecast is measured in terms of the consumer price index (CPI) or harmonised index of consumer prices (HICP) for euro area countries, the euro area aggregate and the United Kingdom.
#
# Inflation measures the general evolution of prices. It is defined as the change in the prices of a basket of goods and services that are typically purchased by households. Projections are based on an assessment of the economic climate in individual countries and the world economy, using a combination of model-based analyses and expert judgement. The indicator is expressed in annual growth rates.
#
# #### Data Structure
#
# This is actually a relatively simple dataset and it contains the following variables:
#
# * LOCATION - the country in a 3 letter code, for example Australia is AUS
# * INDICATOR - the name of the measure always CPIFORECAST
# * TIME - the year for older data one measure per year but in newer measures we have data in quarters
# * Value - The % change in inflation for the time period

# %%
# import pandas here
import pandas as pd

# import the file and convert to a dataframe
df = pd.read_csv("oecd_inflation.csv")

# look at the top of the dataframe
df.head()
# Out:
#    Unnamed: 0 LOCATION    INDICATOR  TIME     Value
# 0           0      AUS  CPIFORECAST  1961  2.287582
# 1           1      AUS  CPIFORECAST  1962 -0.319489
# 2           2      AUS  CPIFORECAST  1963  0.641026
# 3           3      AUS  CPIFORECAST  1964  2.866242
# 4           4      AUS  CPIFORECAST  1965  3.405573

# %% [markdown]
# # Questions
#
# ##### Create a new dataframe called `df_australia` that contains only the data about Australia?

# %%
# answer in this cell

# %% [markdown]
# ##### Write the code to show the year with the highest inflation level from the `df_australia`dataframe?

# %%
# answer in this cell

# %% [markdown]
# ##### Write the code to show the year with the lowest inflation level from the `df_australia`dataframe?

# %%
# answer in this cell

# %% [markdown]
# ##### Write the code to show the mean annual inflation level from the `df_australia`dataframe?

# %%
# answer in this cell

# %% [markdown]
# ##### Write the code to create a dataframe from the main df called `df_usa`?

# %%
# answer in this cell

# %% [markdown]
# ##### Write the code to show the mean annual inflation level from the `df_usa` dataframe, write the code to show the year with the highest inflation and the lowest inflation?

# %%
# answer in this cell

# %% [markdown]
# ##### Create a line graph that shows the USA's inflation level, put the years on the x axis and the inflation value on the y axis?

# %%
# answer in this cell

# %% [markdown]
# ##### Create a bar plot that shows the USA's inflation level, put the years on the x axis and the inflation value on the y axis?

# %%
# answer in this cell

# %% [markdown]
# ##### Create a second line graph, this time plot two lines onto the graph, one for Australia and one for the USA?

# %%
# answer in this cell

# %% [markdown]
# ##### Create a line graph that shows the following for all the years of data that are available in the CSV:
#
# * Inflation for Australia
# * Inflation for the UK
# * Inflation for the USA
# * Inflation for France
#
# Add a legend to the plot, make each of the lines a different colour, add axis titles and a main title, add grid lines to the plot.

# %%
# answer in this cell
