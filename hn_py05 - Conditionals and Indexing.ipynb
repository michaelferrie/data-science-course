# %% [markdown]
# # Computer Programming and Software Development Introduction 5: Conditionals and Indexing
# #### Notebook by: michael.ferrie@edinburghcollege.ac.uk
# #### Edinburgh College, Sep 2021

# %% [markdown]
# ## Part 1 - Conditional Statements

# %% [markdown]
# <div class="alert alert-block alert-danger">
#     <b>Note:</b> Make sure you run every cell, click on the cell and press <b>CTRL+ENTER</b>
# </div>

# %% [markdown]
# A conditional is sometimes called a *test* or an *if statement* and is made of three parts:
#
# 1. the predicate
#
# 2. the consequent
#
# 3. and the alternative
#
# Conditionals are very common, we use these to get the computer to stop what it is doing and check a condition. This is sometimes called if then else. Consider the diagram that shows the basic structure of a conditional:
#
# ![png conditional statement](data:image/png;base64,...)

# %% [markdown]
# In the diagram we can see the three parts of the conditional, the predicate in A, the consequent in B and the alternative in C.  Let's say we want to check of a number is greater than 5 - that is the predicate.
#
# If the number is greater than 5 then I would like to computer to say “Yes its higher than 5” that is the consequent, if the number is lower than 5 I would like the computer to say “No this is lower than 5.”
#
# To create a conditional in python the syntax is as follows:
#
# ` my_number = 10 `
#
# ` if my_number > 5: `
#
# `   print("Yes its higher than 5") `
#
# ` else: `
#
# `   print("No this is lower than 5") `
#
# In this example we have a variable which is an integer with the value of 10, then we create a conditional with the predicate of the number being greater than 10, if this is true we print the consequent, otherwise we print the alternative.
#
# Try running the example, change the value of my number to 4 and see the change in output:

# %%
# run this cell, to see the conditional example

my_number = 10

if my_number > 5:
  print("Yes it's higher than 5")
else:
  print("No it's is lower than 5")
# Out:
# Yes it's higher than 5

# %% [markdown]
# ## Part 2 - Indexing
#
# Often in programming languages, individual items in an ordered set of data can be accessed directly using a numeric index or key value. This process is referred to as indexing.
# In Python, strings are ordered sequences of character data, and thus can be indexed in this way. Individual characters in a string can be accessed by specifying the string name followed by a number in square brackets ([]).
#
# String indexing in Python is zero-based: the first character in the string has index 0, the next has index 1, and so on. The index of the last character will be the length of the string minus one.
#
# Objects of type str are used to represent strings of characters. Literals of type str can be written using either single or double quotes, e.g., 'abc' or "abc". The literal '123' denotes a string of three characters, not the number one hundred twenty-three. Run the following code cells:
# • The length of a string can be found using the len function. For example, the value of len('abc') is 3.
#
# • Indexing can be used to extract individual characters from a string. In Python, all indexing is zero-based. For example, typing 'abc'[0] into the interpreter will cause it to display the string 'a'. Typing 'abc'[3] will produce the error message IndexError: string index out of range. Since Python uses 0 to indicate the first element of a string, the last element of a string of length 3 is accessed using the index 2. Negative numbers are used to index from the end of a string. For example, the value of 'abc'[-1] is 'c'.
#
# • Slicing is used to extract substrings of arbitrary length. If s is a string, the expression s[start:end] denotes the substring of s that starts at index start and ends at index end-1. For example, 'abc'[1:3] = 'bc'. Why does it end at index end-1 rather than end? So that expressions such as 'abc'[0:len('abc')] have the value one might expect. If the value before the colon is omitted, it defaults to 0. If the value after the colon is omitted, it defaults to the length of the string. Consequently, the expression 'abc'[:] is semantically equivalent to the more verbose 'abc'[0:len('abc')].
#
# Look at the following graphic to show the index values in a string
# ![index values png](data:image/png;base64,...)
#
#
# * Run the following examples to see indexing in operation

# %%
my_example_string = "I like python"

# Print the zeroth index value
print(my_example_string[0])

# Print the second value
print(my_example_string[0])

# Print the value from the end using the negative index
print(my_example_string[-1])

# Print a range of values
print(my_example_string[2:5])
# Out:
# I
# I
# n
# lik

# %% [markdown]
# # Part 2 - Questions
# <div class="alert alert-block alert-success">
# <b>How to answer: </b> Add your code to the code cell below each question.
# </div>

# %% [markdown]
# 1 Run the program in the next cell, modify the program so that it prints out `b is greater than a`?

# %%
# Program for question 1
a = 33
b = 33
if b > a:
  print("b is greater than a")
elif a == b:
  print("a and b are equal")
# Out:
# a and b are equal

# %% [markdown]
# 2 Run the program in the next cell, modify the program so that it prints out `a is greater than b`?

# %%
# Program for question 2
a = 5
b = 33
if b > a:
  print("b is greater than a")
elif a == b:
  print("a and b are equal")
else:
  print("a is greater than b")
# Out:
# b is greater than a

# %% [markdown]
# 3 Create the following program, then change the value of the celsius variable to see the output in fahrenheit, what value in celcius gets closest to 100 degrees in fahrenheit - change the variable to this value?

# %%
celsius = 15
fahrenheit = (celsius * 1.8) + 32
print ("The temperature in fahrenheit is: ", (fahrenheit))
# Out:
# The temperature in fahrenheit is:  59.0

# %% [markdown]
# 4 Go to xe.com and check the exchange rate of €1 to £GBP, when I last checked this (Feb, 2021) it was €0.87 to £1. Create a program with one float variable called euros. Then modify the program from Q3 to print out the value in £GBP. Add a screenshot here of this program running:

# %%
# code here for Q4

# %% [markdown]
# 5 Modify the program created in Q4 add two new print statements and two new variables to print out the value of the euro variable in $USD (United States Dollar) and $BRL (Brazillian Real). Add a screenshot here of this program running:

# %%
# code here for Q5

# %% [markdown]
# 6 Create the following string, then answer the questions based on the string:
# ` my_string = "Most people fail in life because they major in minor things" `

# %%
# create the string for Q6 in this cell, below this line

# %% [markdown]
# 6i Using the index write the code to print only character 2 of the string?

# %%
# code for 6i below this line

# %% [markdown]
# 6ii Using the index range write the code to print the first 3 characters of the sting?

# %%
# code for 6ii below this line

# %% [markdown]
# 6iii Using the negative index write the code to print the last 3 characters of the string?

# %%
# code for 6iii below this line

# %% [markdown]
# 6iv Print the length of the string, using a built-in function?

# %%
# code for 6iv below this line

# %% [markdown]
# 6v Using the index range write the code to print the character range from 10-15 of the string?

# %%
# code for 6v below this line

# %% [markdown]
# <div class="alert alert-block alert-danger">
#     <b>Q7 Challenge Question:</b> Write a program that will only print the vowels in <b>my_string</b>?</div>

# %%
my_string = "Heal the world, make it a better place"
# code for Q7 below this line
